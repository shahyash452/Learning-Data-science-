# %%
import pandas as pd
# import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bhp.csv')
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df['price_per_sqft'].describe()
# Out:
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
min_threshold = df['price_per_sqft'].quantile(0.001)
max_threshold = df['price_per_sqft'].quantile(0.999)
min_threshold, max_threshold
# Out:
# (1366.184, 50959.36200000098)

# %%
df[(df.price_per_sqft < min_threshold) | (df.price_per_sqft > max_threshold)].head()
# Out:
#        location       size  total_sqft  bath  price  bhk  price_per_sqft
# 345       other  3 Bedroom        11.0   3.0   74.0    3          672727
# 665   Yelahanka      3 BHK     35000.0   3.0  130.0    3             371
# 798       other  4 Bedroom     10961.0   4.0   80.0    4             729
# 1005      other      1 BHK        15.0   1.0   30.0    1          200000
# 1106      other  5 Bedroom        24.0   2.0  150.0    5          625000

# %%
plt.hist(new_df.price_per_sqft , bins=50, rwidth=0.8)
plt.show()

# %% [markdown]
# # Using Standard Deviation

# %%
new_df = df[(df.price_per_sqft > min_threshold) & (df.price_per_sqft < max_threshold)]
new_df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
mean = new_df.price_per_sqft.mean()
std  = new_df.price_per_sqft.std()
mean,std
# Out:
# (6663.6537351958705, 4141.020700174613)

# %%
df[ (df.price_per_sqft > mean+4*std ) | (df.price_per_sqft < mean-4*std) ]
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 345              other  3 Bedroom        11.0   3.0    74.0    3
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft
# 9               36274
# 45              33333
# 190             27083
# 345            672727
# 733             23719
# ...               ...
# ...

# %%
df1 = df[ (df.price_per_sqft < mean+4*std ) & (df.price_per_sqft > mean-4*std) ]
df1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
plt.hist(df1.price_per_sqft , bins=20, rwidth=0.8)
plt.show()

# %%
df1['price_per_sqft'].describe()
# Out:
# count    13061.000000
# mean      6443.310926
# std       3490.657516
# min        267.000000
# 25%       4255.000000
# 50%       5411.000000
# 75%       7222.000000
# max      23214.000000
# Name: price_per_sqft, dtype: float64
